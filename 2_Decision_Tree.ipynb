# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("diabetes.csv")
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
from sklearn.model_selection import train_test_split
x = df
y = x.pop('Outcome')
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.1)

# %%
#create a decision tree model
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(max_depth=8)

# %%
model = model.fit(x_train, y_train)

from sklearn import tree
tree.plot_tree(model)
# Out:
# [Text(0.4167239010989011, 0.9444444444444444, 'X[1] <= 127.5\ngini = 0.451\nsamples = 691\nvalue = [454, 237]'),
#  Text(0.17994505494505494, 0.8333333333333334, 'X[7] <= 28.5\ngini = 0.299\nsamples = 432\nvalue = [353, 79]'),
#  Text(0.10302197802197802, 0.7222222222222222, 'X[5] <= 45.4\ngini = 0.149\nsamples = 247\nvalue = [227, 20]'),
#  Text(0.06868131868131869, 0.6111111111111112, 'X[5] <= 31.4\ngini = 0.13\nsamples = 243\nvalue = [226, 17]'),
#  Text(0.03296703296703297, 0.5, 'X[0] <= 7.5\ngini = 0.028\nsamples = 140\nvalue = [138, 2]'),
#  Text(0.02197802197802198, 0.3888888888888889, 'X[6] <= 0.672\ngini = 0.014\nsamples = 139\nvalue = [138, 1]'),
#  Text(0.01098901098901099, 0.2777777777777778, 'gini = 0.0\nsamples = 121\nvalue = [121, 0]'),
#  Text(0.03296703296703297, 0.2777777777777778, 'X[6] <= 0.686\ngini = 0.105\nsamples = 18\nvalue = [17, 1]'),
#  Text(0.02197802197802198, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.04395604395604396, 0.16666666666666666, 'gini = 0.0\nsamples = 17\nvalue = [17, 0]'),
#  Text(0.04395604395604396, 0.3888888888888889, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1043956043956044, 0.5, 'X[6] <= 0.501\ngini = 0.249\nsamples = 103\nvalue = [88, 15]'),
#  Text(0.06593406593406594, 0.3888888888888889, 'X[2] <= 22.0\ngini = 0.121\nsamples = 62\nvalue = [58, 4]'),
#  Text(0.054945054945054944, 0.2777777777777778, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.07692307692307693, 0.2777777777777778, 'X[4] <= 38.0\ngini = 0.094\nsamples = 61\nvalue = [58, 3]'),
#  Text(0.06593406593406594, 0.16666666666666666, 'X[2] <= 55.0\ngini = 0.245\nsamples = 21\nvalue = [18, 3]'),
#  Text(0.054945054945054944, 0.05555555555555555, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.07692307692307693, 0.05555555555555555, 'gini = 0.18\nsamples = 20\nvalue = [18, 2]'),
#  Text(0.08791208791208792, 0.16666666666666666, 'gini = 0.0\nsamples = 40\nvalue = [40, 0]'),
#  Text(0.14285714285714285, 0.3888888888888889, 'X[6] <= 0.544\ngini = 0.393\nsamples = 41\nvalue = [30, 11]'),
#  Text(0.12087912087912088, 0.2777777777777778, 'X[4] <= 147.0\ngini = 0.5\nsamples = 10\nvalue = [5, 5]'),
#  Text(0.10989010989010989, 0.16666666666666666, 'X[2] <= 61.0\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.0989010989010989, 0.05555555555555555, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.12087912087912088, 0.05555555555555555, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.13186813186813187, 0.16666666666666666, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.16483516483516483, 0.2777777777777778, 'X[6] <= 0.69\ngini = 0.312\nsamples = 31\nvalue = [25, 6]'),
#  Text(0.15384615384615385, 0.16666666666666666, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(0.17582417582417584, 0.16666666666666666, 'X[5] <= 34.85\ngini = 0.469\nsamples = 16\nvalue = [10, 6]'),
#  Text(0.16483516483516483, 0.05555555555555555, 'gini = 0.49\nsamples = 7\nvalue = [3, 4]'),
#  Text(0.18681318681318682, 0.05555555555555555, 'gini = 0.346\nsamples = 9\nvalue = [7, 2]'),
#  Text(0.13736263736263737, 0.6111111111111112, 'X[7] <= 22.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.12637362637362637, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.14835164835164835, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.25686813186813184, 0.7222222222222222, 'X[5] <= 26.35\ngini = 0.434\nsamples = 185\nvalue = [126, 59]'),
#  Text(0.2087912087912088, 0.6111111111111112, 'X[5] <= 9.65\ngini = 0.102\nsamples = 37\nvalue = [35, 2]'),
#  Text(0.1978021978021978, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.21978021978021978, 0.5, 'gini = 0.0\nsamples = 35\nvalue = [35, 0]'),
#  Text(0.30494505494505497, 0.6111111111111112, 'X[1] <= 99.5\ngini = 0.474\nsamples = 148\nvalue = [91, 57]'),
#  Text(0.24175824175824176, 0.5, 'X[1] <= 28.5\ngini = 0.291\nsamples = 51\nvalue = [42, 9]'),
#  Text(0.23076923076923078, 0.3888888888888889, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.25274725274725274, 0.3888888888888889, 'X[4] <= 88.0\ngini = 0.245\nsamples = 49\nvalue = [42, 7]'),
#  Text(0.23076923076923078, 0.2777777777777778, 'X[6] <= 1.16\ngini = 0.165\nsamples = 44\nvalue = [40, 4]'),
#  Text(0.21978021978021978, 0.16666666666666666, 'X[7] <= 44.5\ngini = 0.13\nsamples = 43\nvalue = [40, 3]'),
#  Text(0.2087912087912088, 0.05555555555555555, 'gini = 0.057\nsamples = 34\nvalue = [33, 1]'),
#  Text(0.23076923076923078, 0.05555555555555555, 'gini = 0.346\nsamples = 9\nvalue = [7, 2]'),
#  Text(0.24175824175824176, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.27472527472527475, 0.2777777777777778, 'X[2] <= 69.0\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.26373626373626374, 0.16666666666666666, 'X[0] <= 9.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.25274725274725274, 0.05555555555555555, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.27472527472527475, 0.05555555555555555, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2857142857142857, 0.16666666666666666, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.36813186813186816, 0.5, 'X[6] <= 0.561\ngini = 0.5\nsamples = 97\nvalue = [49, 48]'),
#  Text(0.34065934065934067, 0.3888888888888889, 'X[7] <= 54.5\ngini = 0.483\nsamples = 71\nvalue = [42, 29]'),
#  Text(0.32967032967032966, 0.2777777777777778, 'X[6] <= 0.218\ngini = 0.496\nsamples = 64\nvalue = [35, 29]'),
#  Text(0.3076923076923077, 0.16666666666666666, 'X[5] <= 34.75\ngini = 0.375\nsamples = 20\nvalue = [15, 5]'),
#  Text(0.2967032967032967, 0.05555555555555555, 'gini = 0.496\nsamples = 11\nvalue = [6, 5]'),
#  Text(0.31868131868131866, 0.05555555555555555, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.3516483516483517, 0.16666666666666666, 'X[6] <= 0.262\ngini = 0.496\nsamples = 44\nvalue = [20, 24]'),
#  Text(0.34065934065934067, 0.05555555555555555, 'gini = 0.278\nsamples = 12\nvalue = [2, 10]'),
#  Text(0.3626373626373626, 0.05555555555555555, 'gini = 0.492\nsamples = 32\nvalue = [18, 14]'),
#  Text(0.3516483516483517, 0.2777777777777778, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.3956043956043956, 0.3888888888888889, 'X[0] <= 6.5\ngini = 0.393\nsamples = 26\nvalue = [7, 19]'),
#  Text(0.38461538461538464, 0.2777777777777778, 'X[3] <= 9.0\ngini = 0.5\nsamples = 14\nvalue = [7, 7]'),
#  Text(0.37362637362637363, 0.16666666666666666, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.3956043956043956, 0.16666666666666666, 'X[6] <= 0.727\ngini = 0.42\nsamples = 10\nvalue = [3, 7]'),
#  Text(0.38461538461538464, 0.05555555555555555, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.4065934065934066, 0.05555555555555555, 'gini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.4065934065934066, 0.2777777777777778, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(0.6535027472527473, 0.8333333333333334, 'X[5] <= 29.95\ngini = 0.476\nsamples = 259\nvalue = [101, 158]'),
#  Text(0.510989010989011, 0.7222222222222222, 'X[1] <= 161.5\ngini = 0.39\nsamples = 64\nvalue = [47, 17]'),
#  Text(0.4725274725274725, 0.6111111111111112, 'X[0] <= 10.5\ngini = 0.286\nsamples = 52\nvalue = [43, 9]'),
#  Text(0.45054945054945056, 0.5, 'X[0] <= 1.5\ngini = 0.245\nsamples = 49\nvalue = [42, 7]'),
#  Text(0.43956043956043955, 0.3888888888888889, 'gini = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(0.46153846153846156, 0.3888888888888889, 'X[0] <= 3.5\ngini = 0.334\nsamples = 33\nvalue = [26, 7]'),
#  Text(0.42857142857142855, 0.2777777777777778, 'X[5] <= 25.5\ngini = 0.486\nsamples = 12\nvalue = [7, 5]'),
#  Text(0.4175824175824176, 0.16666666666666666, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.43956043956043955, 0.16666666666666666, 'X[6] <= 0.304\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.42857142857142855, 0.05555555555555555, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.45054945054945056, 0.05555555555555555, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.4945054945054945, 0.2777777777777778, 'X[6] <= 0.237\ngini = 0.172\nsamples = 21\nvalue = [19, 2]'),
#  Text(0.4835164835164835, 0.16666666666666666, 'X[1] <= 146.5\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.4725274725274725, 0.05555555555555555, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.4945054945054945, 0.05555555555555555, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.5054945054945055, 0.16666666666666666, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(0.4945054945054945, 0.5, 'X[7] <= 50.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.4835164835164835, 0.3888888888888889, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.5054945054945055, 0.3888888888888889, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5494505494505495, 0.6111111111111112, 'X[7] <= 62.5\ngini = 0.444\nsamples = 12\nvalue = [4, 8]'),
#  Text(0.5384615384615384, 0.5, 'X[2] <= 81.0\ngini = 0.32\nsamples = 10\nvalue = [2, 8]'),
#  Text(0.5274725274725275, 0.3888888888888889, 'X[7] <= 27.5\ngini = 0.198\nsamples = 9\nvalue = [1, 8]'),
#  Text(0.5164835164835165, 0.2777777777777778, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5384615384615384, 0.2777777777777778, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.5494505494505495, 0.3888888888888889, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5604395604395604, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.7960164835164835, 0.7222222222222222, 'X[1] <= 157.5\ngini = 0.4\nsamples = 195\nvalue = [54, 141]'),
#  Text(0.6442307692307693, 0.6111111111111112, 'X[2] <= 61.0\ngini = 0.479\nsamples = 111\nvalue = [44, 67]'),
#  Text(0.5824175824175825, 0.5, 'X[7] <= 40.5\ngini = 0.124\nsamples = 15\nvalue = [1, 14]'),
#  Text(0.5714285714285714, 0.3888888888888889, 'gini = 0.0\nsamples = 13\nvalue = [0, 13]'),
#  Text(0.5934065934065934, 0.3888888888888889, 'X[5] <= 39.2\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.5824175824175825, 0.2777777777777778, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6043956043956044, 0.2777777777777778, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7060439560439561, 0.5, 'X[7] <= 30.5\ngini = 0.495\nsamples = 96\nvalue = [43, 53]'),
#  Text(0.6483516483516484, 0.3888888888888889, 'X[5] <= 41.8\ngini = 0.444\nsamples = 39\nvalue = [26, 13]'),
#  Text(0.6263736263736264, 0.2777777777777778, 'X[6] <= 1.141\ngini = 0.358\nsamples = 30\nvalue = [23, 7]'),
#  Text(0.6153846153846154, 0.16666666666666666, 'X[0] <= 4.5\ngini = 0.293\nsamples = 28\nvalue = [23, 5]'),
#  Text(0.6043956043956044, 0.05555555555555555, 'gini = 0.211\nsamples = 25\nvalue = [22, 3]'),
#  Text(0.6263736263736264, 0.05555555555555555, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.6373626373626373, 0.16666666666666666, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6703296703296703, 0.2777777777777778, 'X[1] <= 142.5\ngini = 0.444\nsamples = 9\nvalue = [3, 6]'),
#  Text(0.6593406593406593, 0.16666666666666666, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.6813186813186813, 0.16666666666666666, 'X[6] <= 0.373\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.6703296703296703, 0.05555555555555555, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6923076923076923, 0.05555555555555555, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.7637362637362637, 0.3888888888888889, 'X[6] <= 0.429\ngini = 0.419\nsamples = 57\nvalue = [17, 40]'),
#  Text(0.7362637362637363, 0.2777777777777778, 'X[5] <= 45.55\ngini = 0.494\nsamples = 27\nvalue = [12, 15]'),
#  Text(0.7252747252747253, 0.16666666666666666, 'X[5] <= 32.45\ngini = 0.496\nsamples = 22\nvalue = [12, 10]'),
#  Text(0.7142857142857143, 0.05555555555555555, 'gini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.7362637362637363, 0.05555555555555555, 'gini = 0.492\nsamples = 16\nvalue = [7, 9]'),
#  Text(0.7472527472527473, 0.16666666666666666, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.7912087912087912, 0.2777777777777778, 'X[5] <= 38.6\ngini = 0.278\nsamples = 30\nvalue = [5, 25]'),
#  Text(0.7692307692307693, 0.16666666666666666, 'X[2] <= 67.0\ngini = 0.091\nsamples = 21\nvalue = [1, 20]'),
#  Text(0.7582417582417582, 0.05555555555555555, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.7802197802197802, 0.05555555555555555, 'gini = 0.0\nsamples = 19\nvalue = [0, 19]'),
#  Text(0.8131868131868132, 0.16666666666666666, 'X[2] <= 83.0\ngini = 0.494\nsamples = 9\nvalue = [4, 5]'),
#  Text(0.8021978021978022, 0.05555555555555555, 'gini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.8241758241758241, 0.05555555555555555, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.9478021978021978, 0.6111111111111112, 'X[5] <= 46.1\ngini = 0.21\nsamples = 84\nvalue = [10, 74]'),
#  Text(0.9175824175824175, 0.5, 'X[6] <= 0.343\ngini = 0.165\nsamples = 77\nvalue = [7, 70]'),
#  Text(0.8901098901098901, 0.3888888888888889, 'X[5] <= 35.3\ngini = 0.337\nsamples = 28\nvalue = [6, 22]'),
#  Text(0.8791208791208791, 0.2777777777777778, 'X[6] <= 0.256\ngini = 0.48\nsamples = 15\nvalue = [6, 9]'),
#  Text(0.8571428571428571, 0.16666666666666666, 'X[5] <= 33.9\ngini = 0.346\nsamples = 9\nvalue = [2, 7]'),
#  Text(0.8461538461538461, 0.05555555555555555, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.8681318681318682, 0.05555555555555555, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.9010989010989011, 0.16666666666666666, 'X[7] <= 36.0\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.8901098901098901, 0.05555555555555555, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.9120879120879121, 0.05555555555555555, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.9010989010989011, 0.2777777777777778, 'gini = 0.0\nsamples = 13\nvalue = [0, 13]'),
#  Text(0.945054945054945, 0.3888888888888889, 'X[1] <= 166.0\ngini = 0.04\nsamples = 49\nvalue = [1, 48]'),
#  Text(0.9340659340659341, 0.2777777777777778, 'X[7] <= 48.0\ngini = 0.18\nsamples = 10\nvalue = [1, 9]'),
#  Text(0.9230769230769231, 0.16666666666666666, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.945054945054945, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9560439560439561, 0.2777777777777778, 'gini = 0.0\nsamples = 39\nvalue = [0, 39]'),
#  Text(0.978021978021978, 0.5, 'X[4] <= 177.5\ngini = 0.49\nsamples = 7\nvalue = [3, 4]'),
#  Text(0.967032967032967, 0.3888888888888889, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.989010989010989, 0.3888888888888889, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]')]

# %%
pred_y = model.predict(x_test)

# %%
print('number of correct preditions are')
diff = list(pred_y - y_test) 
print(diff.count(0)," out of ",len(diff))
# Out:
# number of correct preditions are
# 53  out of  77

# %%
model.predict(np.array(df.iloc[2]).reshape(1, -1))
# Out:
# D:\Anaconda\Software\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1], dtype=int64)
